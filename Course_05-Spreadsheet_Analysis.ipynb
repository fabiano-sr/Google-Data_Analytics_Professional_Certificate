# %%
import gspread
import requests
from oauth2client.service_account import ServiceAccountCredentials
import pandas as pd

# %%
# Definir escopo de acesso ao Drive
scopes = [
    "https://spreadsheets.google.com/feeds",
    "https://www.googleapis.com/auth/drive"
]

# %%
# Criar as credenciais de acesso
creds = ServiceAccountCredentials.from_json_keyfile_name(
    filename="cursobigquery_OAuth_2-0.json",
    scopes=scopes
    )
# Criar o client
client = gspread.authorize(creds)

# %%
print(client)
# Out:
# <gspread.client.Client object at 0x0000023BC1C7A2D0>

# %% [markdown]
# #### Fixando o cabeçalho da Planilha

# %%
# Abrir a planilha
spreadsheet = client.open("Course_05-Movie_Data")

# Obter o ID da planilha
spreadsheet_id = spreadsheet.id

# URL da API
url = f"https://sheets.googleapis.com/v4/spreadsheets/{spreadsheet_id}:batchUpdate"

# ID da aba (gid) - normalmente é 0 para a primeira aba
sheet_id = spreadsheet.sheet1._properties['sheetId']

# Requisição para fixar o Header
payload = {
    "requests": [
        {
            "updateSheetProperties": {
                "properties":{
                    "sheetId": sheet_id,
                    "gridProperties": {"frozenRowCount": 1}
                },
                "fields": "gridProperties.frozenRowCount"
            }
        }
    ]
}

token = creds.get_access_token().access_token

headers = {
    "Authorization": f"Bearer {token}",
    "Content-Type": "application/json"
}

response = requests.post(url, json=payload, headers=headers)

print(response.json())
# Out:
# {'spreadsheetId': '1ydeQcHioX7qh0oDJEZqb-zx7SpeCNZrbMNF738dLQ6Q', 'replies': [{}]}

# %% [markdown]
# #### Carregando a Planilha

# %%
planilha = client.open(
    title="Course_05-Movie_Data", 
    folder_id="1VeZ1jCJLUNXSDYpJrchCjPTtr5iZ7BKw")

# %%
planilha = planilha.get_worksheet(0)

# %%
planilha.get_all_records()
# Out:
# [{'Movie Title': '10 Cloverfield Lane',
#   'Release Date': '2016-03-08',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/10_Cloverfield_Lane',
#   'Genre': 'Thriller',
#   'Director 1': 'Dan Trachtenberg',
#   'Director 2': '',
#   'Cast 1': 'Mary Elizabeth Winstead',
#   'Cast 2': 'John Goodman',
#   'Cast 3': 'John Gallagher',
#   'Cast 4': '',
#   'Cast 5': '',
#   'Budget': '$15,000,000.00',
#   'Revenue': '$108,300,000.00'},
#  {'Movie Title': '13 Hours: The Secret Soldiers of Benghazi',
#   'Release Date': '2016-01-15',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/13_Hours:_The_Secret_Soldiers_of_Benghazi',
#   'Genre': 'Action',
#   'Director 1': 'Michael Bay',
#   'Director 2': '',
#   'Cast 1': 'James Badge Dale',
#   'Cast 2': 'John Krasinski',
#   'Cast 3': 'Toby Stephens',
#   'Cast 4': 'Pablo Schreiber',
#   'Cast 5': 'Max Martini',
#   'Budget': '$45,000,000.00',
#   'Revenue': '$69,400,000.00'},
#  {'Movie Title': '2 Guns',
#   'Release Date': '2013-08-02',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/2_Guns',
#   'Genre': 'Action',
#   'Director 1': 'Baltasar Kormákur',
#   'Director 2': '',
#   'Cast 1': 'Mark Wahlberg',
#   'Cast 2': 'Denzel Washington',
#   'Cast 3': 'Paula Patton',
#   'Cast 4': 'Bill Paxton',
#   'Cast 5': 'Edward James Olmos',
#   'Budget': '$61,000,000.00',
#   'Revenue': '$131,900,000.00'},
#  {'Movie Title': '21 Jump Street',
#   'Release Date': '2012-03-16',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/21_Jump_Street_(film)',
#   'Genre': 'Comedy',
#   'Director 1': 'Phil Lord',
#   'Director 2': 'Chris Miller',
#   'Cast 1': 'Jonah Hill',
#   'Cast 2': 'Channing Tatum',
#   'Cast 3': 'Ice Cube',
#   'Cast 4': 'Brie Larson',
#   'Cast 5': 'Rob Riggle',
#   'Budget': '$55,000,000.00',
#   'Revenue': '$201,500,000.00'},
#  {'Movie Title': '22 Jump Street',
#   'Release Date': '2014-06-04',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/22_Jump_Street',
#   'Genre': 'Action',
#   'Director 1': 'Phil Lord',
#   'Director 2': 'Chris Miller',
#   'Cast 1': 'Channing Tatum',
#   'Cast 2': 'Jonah Hill',
#   'Cast 3': 'Ice Cube',
#   'Cast 4': '',
#   'Cast 5': '',
#   'Budget': '$84,500,000.00',
#   'Revenue': '$331,300,000.00'},
#  {'Movie Title': '300: Rise of an Empire',
#   'Release Date': '2014-03-04',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/300:_Rise_of_an_Empire',
#   'Genre': 'Action',
#   'Director 1': 'Noam Murro',
#   'Director 2': '',
#   'Cast 1': 'Rodrigo Santoro',
#   'Cast 2': 'Eva Green',
#   'Cast 3': 'Sullivan Stapleton',
#   'Cast 4': 'Hans Matheson',
#   'Cast 5': 'Lena Headey',
#   'Budget': '$110,000,000.00',
#   'Revenue': '$337,600,000.00'},
#  {'Movie Title': 42,
#   'Release Date': '2013-04-12',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/42_(film)',
#   'Genre': 'Biography',
#   'Director 1': 'Brian Helgeland',
#   'Director 2': '',
#   'Cast 1': 'Harrison Ford',
#   'Cast 2': 'Chadwick Boseman',
#   'Cast 3': 'Christopher Meloni',
#   'Cast 4': 'Ryan Merriman',
#   'Cast 5': 'Andre Holland',
#   'Budget': '$40,000,000.00',
#   'Revenue': '$97,500,000.00'},
#  {'Movie Title': 71,
#   'Release Date': '2014-02-07',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/%252771_(film)',
#   'Genre': 'Action',
#   'Director 1': 'Yann Demange',
#   'Director 2': '',
#   'Cast 1': "Jack O'Connell",
#   'Cast 2': 'Richard Dormer',
#   'Cast 3': 'Sean Harris',
#   'Cast 4': 'Sam Reid',
#   'Cast 5': '',
#   'Budget': '$8,100,000.00',
#   'Revenue': '$2,900,000.00'},
#  {'Movie Title': '90 Minutes in Heaven',
#   'Release Date': '2015-09-11',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/90_Minutes_in_Heaven_(film)',
#   'Genre': 'Drama',
#   'Director 1': 'Michael Polish',
#   'Director 2': '',
#   'Cast 1': 'Hayden Christensen',
#   'Cast 2': 'Kate Bosworth',
#   'Cast 3': 'Dwight Yoakam',
#   'Cast 4': 'Michael W. Smith',
#   'Cast 5': '',
#   'Budget': '$5,000,000.00',
#   'Revenue': '$4,800,000.00'},
#  {'Movie Title': 'A Good Day to Die Hard',
#   'Release Date': '2013-02-14',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/A_Good_Day_to_Die_Hard',
#   'Genre': 'Action',
#   'Director 1': 'John Moore',
#   'Director 2': '',
#   'Cast 1': 'Bruce Willis',
#   'Cast 2': 'Jai Courtney',
#   'Cast 3': 'Sebastian Koch',
#   'Cast 4': 'Yuliya Snigir',
#   'Cast 5': 'Radivoje Bukvić',
#   'Budget': '$92,000,000.00',
#   'Revenue': '$304,700,000.00'},
#  {'Movie Title': 'A Haunted House',
#   'Release Date': '2013-01-11',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/A_Haunted_House_(film)',
#   'Genre': 'Comedy',
#   'Director 1': 'Michael Tiddes',
#   'Director 2': '',
#   'Cast 1': 'Marlon Wayans',
#   'Cast 2': 'Nick Swardson',
#   'Cast 3': 'David Koechner',
#   'Cast 4': 'Essence Atkins',
#   'Cast 5': 'Cedric the Entertainer',
#   'Budget': '$2,500,000.00',
#   'Revenue': '$60,100,000.00'},
#  {'Movie Title': 'A Haunted House 2',
#   'Release Date': '2014-04-18',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/A_Haunted_House_2',
#   'Genre': 'Comedy',
#   'Director 1': 'Michael Tiddes',
#   'Director 2': '',
#   'Cast 1': 'Marlon Wayans',
#   'Cast 2': 'Jaime Pressly',
#   'Cast 3': 'Essence Atkins',
#   'Cast 4': 'Cedric the Entertainer',
#   'Cast 5': 'Gabriel Iglesias',
#   'Budget': '$4,000,000.00',
#   'Revenue': '$24,000,000.00'},
#  {'Movie Title': 'A Long Way Down',
#   'Release Date': '2014-02-10',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/A_Long_Way_Down_(film)',
#   'Genre': 'Comedy',
#   'Director 1': 'Pascal Chaumeil',
#   'Director 2': '',
#   'Cast 1': 'Toni Collette',
#   'Cast 2': 'Pierce Brosnan',
#   'Cast 3': 'Aaron Paul',
#   'Cast 4': 'Imogen Poots',
#   'Cast 5': '',
#   'Budget': '$22,700,000.00',
#   'Revenue': '$7,100,000.00'},
#  {'Movie Title': 'A Most Violent Year',
#   'Release Date': '2014-11-06',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/A_Most_Violent_Year',
#   'Genre': 'Action',
#   'Director 1': 'J. C. Chandor',
#   'Director 2': '',
#   'Cast 1': 'Oscar Isaac',
#   'Cast 2': 'Jessica Chastain',
#   'Cast 3': 'Alessandro Nivola',
#   'Cast 4': 'David Oyelowo',
#   'Cast 5': 'Albert Brooks',
#   'Budget': '$20,000,000.00',
#   'Revenue': '$12,000,000.00'},
#  {'Movie Title': 'A Most Wanted Man',
#   'Release Date': '2014-01-19',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/A_Most_Wanted_Man_(film)',
#   'Genre': 'Thriller',
#   'Director 1': 'Anton Corbijn',
#   'Director 2': '',
#   'Cast 1': 'Philip Seymour Hoffman',
#   'Cast 2': 'Rachel McAdams',
#   'Cast 3': 'Robin Wright',
#   'Cast 4': 'Willem Dafoe',
#   'Cast 5': 'Grigoriy Dobrygin',
#   'Budget': '$15,000,000.00',
#   'Revenue': '$36,200,000.00'},
#  {'Movie Title': 'A Thousand Words',
#   'Release Date': '2012-03-09',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/A_Thousand_Words_(film)',
#   'Genre': 'Comedy',
#   'Director 1': 'Brian Robbins',
#   'Director 2': '',
#   'Cast 1': 'Eddie Murphy',
#   'Cast 2': 'Kerry Washington',
#   'Cast 3': 'Cliff Curtis',
#   'Cast 4': 'Clark Duke',
#   'Cast 5': 'Allison Janney',
#   'Budget': '$40,000,000.00',
#   'Revenue': '$22,000,000.00'},
#  {'Movie Title': 'A Walk Among the Tombstones',
#   'Release Date': '2014-09-19',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/A_Walk_Among_the_Tombstones_(film)',
#   'Genre': 'Crime',
#   'Director 1': 'Scott Frank',
#   'Director 2': '',
#   'Cast 1': 'Liam Neeson',
#   'Cast 2': 'Dan Stevens',
#   'Cast 3': 'Ruth Wilson',
#   'Cast 4': 'Boyd Holbrook',
#   'Cast 5': '',
#   'Budget': '$28,000,000.00',
#   'Revenue': '$58,800,000.00'},
#  {'Movie Title': 'A Walk in the Woods',
#   'Release Date': '2015-01-23',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/A_Walk_in_the_Woods_(film)',
#   'Genre': 'Adventure',
#   'Director 1': 'Ken Kwapis',
#   'Director 2': '',
#   'Cast 1': 'Robert Redford',
#   'Cast 2': 'Nick Nolte',
#   'Cast 3': 'Emma Thompson',
#   'Cast 4': '',
#   'Cast 5': '',
#   'Budget': '$8,000,000.00',
#   'Revenue': '$36,000,000.00'},
#  {'Movie Title': 'Abraham Lincoln: Vampire Hunter',
#   'Release Date': '2012-06-22',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Abraham_Lincoln:_Vampire_Hunter_(film)',
#   'Genre': 'Horror',
#   'Director 1': 'Timur Bekmambetov',
#   'Director 2': '',
#   'Cast 1': 'Benjamin Walker',
#   'Cast 2': 'Dominic Cooper',
#   'Cast 3': 'Anthony Mackie',
#   'Cast 4': 'Mary Elizabeth Winstead',
#   'Cast 5': 'Rufus Sewell',
#   'Budget': '$99,500,000.00',
#   'Revenue': '$116,400,000.00'},
#  {'Movie Title': 'After Earth',
#   'Release Date': '2013-05-31',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/After_Earth',
#   'Genre': 'Sci-Fi',
#   'Director 1': 'M. Night Shyamalan',
#   'Director 2': '',
#   'Cast 1': 'Jaden Smith',
#   'Cast 2': 'Will Smith',
#   'Cast 3': 'Isabelle Fuhrman',
#   'Cast 4': 'Zoe Kravitz',
#   'Cast 5': '',
#   'Budget': '$130,000,000.00',
#   'Revenue': '$243,800,000.00'},
#  {'Movie Title': "Ain't Them Bodies Saints",
#   'Release Date': '2013-08-16',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Ain%2527t_Them_Bodies_Saints',
#   'Genre': 'Drama',
#   'Director 1': 'David Lowery',
#   'Director 2': '',
#   'Cast 1': 'Casey Affleck',
#   'Cast 2': 'Rooney Mara',
#   'Cast 3': 'Ben Foster',
#   'Cast 4': 'Rami Malek',
#   'Cast 5': 'Keith Carradine',
#   'Budget': '$4,000,000.00',
#   'Revenue': '$1,000,000.00'},
#  {'Movie Title': 'Alex Cross',
#   'Release Date': '2012-10-19',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Alex_Cross_(film)',
#   'Genre': 'Crime',
#   'Director 1': 'Rob Cohen',
#   'Director 2': '',
#   'Cast 1': 'Tyler Perry',
#   'Cast 2': 'Matthew Fox',
#   'Cast 3': 'Rachel Nichols',
#   'Cast 4': 'Edward Burns',
#   'Cast 5': 'Jean Reno',
#   'Budget': '$35,000,000.00',
#   'Revenue': '$34,600,000.00'},
#  {'Movie Title': 'Aloha',
#   'Release Date': '2015-05-27',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Aloha_(film)',
#   'Genre': 'Romance',
#   'Director 1': 'Cameron Crowe',
#   'Director 2': '',
#   'Cast 1': 'Bradley Cooper',
#   'Cast 2': 'Emma Stone',
#   'Cast 3': 'Alec Baldwin',
#   'Cast 4': 'Rachel McAdams',
#   'Cast 5': 'Bill Murray',
#   'Budget': '$52,000,000.00',
#   'Revenue': '$26,300,000.00'},
#  {'Movie Title': 'Alvin and the Chipmunks: The Road Chip',
#   'Release Date': '2015-12-18',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Alvin_and_the_Chipmunks:_The_Road_Chip',
#   'Genre': 'Comedy',
#   'Director 1': 'Walt Becker',
#   'Director 2': '',
#   'Cast 1': 'Jason Lee',
#   'Cast 2': 'Tony Hale',
#   'Cast 3': 'Kimberly Williams-Paisley',
#   'Cast 4': 'Josh Green',
#   'Cast 5': 'Bella Thorne',
#   'Budget': '$90,000,000.00',
#   'Revenue': '$234,800,000.00'},
#  {'Movie Title': 'American Reunion',
#   'Release Date': '2012-04-06',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/American_Reunion',
#   'Genre': 'Comedy',
#   'Director 1': 'Jon Hurwitz',
#   'Director 2': '',
#   'Cast 1': 'Alyson Hannigan',
#   'Cast 2': 'Seann William Scott',
#   'Cast 3': 'Tara Reid',
#   'Cast 4': 'Jason Biggs',
#   'Cast 5': 'Eugene Levy',
#   'Budget': '$50,000,000.00',
#   'Revenue': '$235,000,000.00'},
#  {'Movie Title': 'American Sniper',
#   'Release Date': '2014-11-11',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/American_Sniper',
#   'Genre': 'Drama',
#   'Director 1': 'Clint Eastwood',
#   'Director 2': '',
#   'Cast 1': 'Bradley Cooper',
#   'Cast 2': 'Sienna Miller',
#   'Cast 3': 'Max Charles',
#   'Cast 4': 'Luke Grimes',
#   'Cast 5': '',
#   'Budget': '$58,800,000.00',
#   'Revenue': '$547,400,000.00'},
#  {'Movie Title': 'American Ultra',
#   'Release Date': '2015-08-21',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/American_Ultra',
#   'Genre': 'Action',
#   'Director 1': 'Nima Nourizadeh',
#   'Director 2': '',
#   'Cast 1': 'Jesse Eisenberg',
#   'Cast 2': 'Kristen Stewart',
#   'Cast 3': 'Connie Britton',
#   'Cast 4': 'Topher Grace',
#   'Cast 5': 'John Leguizamo',
#   'Budget': '$28,000,000.00',
#   'Revenue': '$27,100,000.00'},
#  {'Movie Title': 'Amy',
#   'Release Date': '2015-06-16',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Amy_(2015_film)',
#   'Genre': 'Biography',
#   'Director 1': 'Asif Kapadia',
#   'Director 2': '',
#   'Cast 1': 'Amy Winehouse',
#   'Cast 2': 'Mitchell Winehouse',
#   'Cast 3': 'Janis Winehouse',
#   'Cast 4': 'Raye Cosbert',
#   'Cast 5': 'Nick Shymansky',
#   'Budget': '$3,400,000.00',
#   'Revenue': '$22,000,000.00'},
#  {'Movie Title': 'Annabelle',
#   'Release Date': '2014-09-26',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Annabelle_(film)',
#   'Genre': 'Horror',
#   'Director 1': 'John R. Leonetti',
#   'Director 2': '',
#   'Cast 1': 'Annabelle Wallis',
#   'Cast 2': 'Alfre Woodard',
#   'Cast 3': 'Eric Ladin',
#   'Cast 4': 'Brian Howe',
#   'Cast 5': '',
#   'Budget': '$6,500,000.00',
#   'Revenue': '$256,900,000.00'},
#  {'Movie Title': 'Annie',
#   'Release Date': '2014-12-07',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Annie_(2014_film)',
#   'Genre': 'Comedy',
#   'Director 1': 'Will Gluck',
#   'Director 2': '',
#   'Cast 1': 'Quvenzhané Wallis',
#   'Cast 2': 'Jamie Foxx',
#   'Cast 3': 'Cameron Diaz',
#   'Cast 4': 'Rose Byrne',
#   'Cast 5': 'Bobby Cannavale',
#   'Budget': '$65,000,000.00',
#   'Revenue': '$133,800,000.00'},
#  {'Movie Title': 'Ant-Man',
#   'Release Date': '2015-06-29',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Ant-Man_(film)',
#   'Genre': 'Action',
#   'Director 1': 'Peyton Reed',
#   'Director 2': '',
#   'Cast 1': 'Paul Rudd',
#   'Cast 2': 'Evangeline Lilly',
#   'Cast 3': 'Corey Stoll',
#   'Cast 4': 'Bobby Cannavale',
#   'Cast 5': 'Michael Peña',
#   'Budget': '$130,000,000.00',
#   'Revenue': '$519,400,000.00'},
#  {'Movie Title': 'Argo',
#   'Release Date': '2012-10-12',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Argo_(2012_film)',
#   'Genre': 'Drama',
#   'Director 1': 'Ben Affleck',
#   'Director 2': '',
#   'Cast 1': 'Ben Affleck',
#   'Cast 2': 'John Goodman',
#   'Cast 3': 'Alan Arkin',
#   'Cast 4': 'Bryan Cranston',
#   'Cast 5': 'Victor Garber',
#   'Budget': '$44,500,000.00',
#   'Revenue': '$232,300,000.00'},
#  {'Movie Title': 'As Above, So Below',
#   'Release Date': '2014-08-29',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/As_Above,_So_Below_(film)',
#   'Genre': 'Horror',
#   'Director 1': 'John Erick Dowdle',
#   'Director 2': '',
#   'Cast 1': 'Drew Dowdle (screenplay)Perdita Weeks',
#   'Cast 2': 'Ben Feldman',
#   'Cast 3': 'Edwin Hodge',
#   'Cast 4': 'François Civil',
#   'Cast 5': 'Marion Lambert',
#   'Budget': '$5,000,000.00',
#   'Revenue': '$5,000,000.00'},
#  {'Movie Title': 'Bad Moms',
#   'Release Date': '2016-07-29',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Bad_Moms',
#   'Genre': 'Comedy',
#   'Director 1': 'Jon Lucas',
#   'Director 2': 'Scott Moore',
#   'Cast 1': 'Mila Kunis',
#   'Cast 2': 'Christina Applegate',
#   'Cast 3': 'Kristen Bell',
#   'Cast 4': 'Jada Pinkett Smith',
#   'Cast 5': 'Kathryn Hahn',
#   'Budget': '$20,000,000.00',
#   'Revenue': '$124,200,000.00'},
#  {'Movie Title': 'Barbershop: The Next Cut',
#   'Release Date': '2016-04-15',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Barbershop:_The_Next_Cut',
#   'Genre': 'Comedy',
#   'Director 1': 'Malcolm D. Lee',
#   'Director 2': '',
#   'Cast 1': 'Ice Cube',
#   'Cast 2': 'Cedric the Entertainer',
#   'Cast 3': 'Nicki Minaj',
#   'Cast 4': 'Regina Hall',
#   'Cast 5': 'Eve',
#   'Budget': '$20,000,000.00',
#   'Revenue': '$55,000,000.00'},
#  {'Movie Title': 'Batman v Superman: Dawn of Justice',
#   'Release Date': '2016-03-19',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Batman_v_Superman:_Dawn_of_Justice',
#   'Genre': 'Action',
#   'Director 1': 'Zack Snyder',
#   'Director 2': '',
#   'Cast 1': 'Ben Affleck',
#   'Cast 2': 'Henry Cavill',
#   'Cast 3': 'Amy Adams',
#   'Cast 4': 'Jesse Eisenberg',
#   'Cast 5': 'Diane Lane',
#   'Budget': '$250,000,000.00',
#   'Revenue': '$872,700,000.00'},
#  {'Movie Title': 'Batman: The Killing Joke',
#   'Release Date': '2016-07-25',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Batman:_The_Killing_Joke_(film)',
#   'Genre': 'Action',
#   'Director 1': 'Sam Liu',
#   'Director 2': 'Bruce Timm',
#   'Cast 1': 'Kevin Conroy',
#   'Cast 2': 'Mark Hamill',
#   'Cast 3': 'Tara Strong',
#   'Cast 4': 'Ray Wise',
#   'Cast 5': '',
#   'Budget': '$3,500,000.00',
#   'Revenue': '$4,400,000.00'},
#  {'Movie Title': 'Battle of the Year',
#   'Release Date': '2013-09-20',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Battle_of_the_Year_(film)',
#   'Genre': 'Musical',
#   'Director 1': 'Benson Lee',
#   'Director 2': '',
#   'Cast 1': 'Josh Holloway',
#   'Cast 2': 'Laz Alonso',
#   'Cast 3': 'Josh Peck',
#   'Cast 4': 'Caity Lotz',
#   'Cast 5': 'Chris Brown',
#   'Budget': '$20,000,000.00',
#   'Revenue': '$16,500,000.00'},
#  {'Movie Title': 'Battleship',
#   'Release Date': '2012-05-18',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Battleship_(film)',
#   'Genre': 'Action',
#   'Director 1': 'Peter Berg',
#   'Director 2': '',
#   'Cast 1': 'Alexander Skarsgård',
#   'Cast 2': 'Taylor Kitsch',
#   'Cast 3': 'Brooklyn Decker',
#   'Cast 4': 'Rihanna',
#   'Cast 5': 'Liam Neeson',
#   'Budget': '$220,000,000.00',
#   'Revenue': '$303,000,000.00'},
#  {'Movie Title': 'Beasts of the Southern Wild',
#   'Release Date': '2012-06-27',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Beasts_of_the_Southern_Wild',
#   'Genre': 'Drama',
#   'Director 1': 'Benh Zeitlin',
#   'Director 2': '',
#   'Cast 1': 'Quvenzhané Wallis',
#   'Cast 2': 'Dwight Henry',
#   'Cast 3': '',
#   'Cast 4': '',
#   'Cast 5': '',
#   'Budget': '$1,800,000.00',
#   'Revenue': '$21,900,000.00'},
#  {'Movie Title': 'Beautiful Creatures',
#   'Release Date': '2013-02-14',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Beautiful_Creatures_(2013_film)',
#   'Genre': 'Fantasy',
#   'Director 1': 'Richard LaGravenese',
#   'Director 2': '',
#   'Cast 1': 'Viola Davis',
#   'Cast 2': 'Alice Englert',
#   'Cast 3': 'Emma Thompson',
#   'Cast 4': 'Emmy Rossum',
#   'Cast 5': 'Jeremy Irons',
#   'Budget': '$60,000,000.00',
#   'Revenue': '$60,100,000.00'},
#  {'Movie Title': 'Before I Go to Sleep',
#   'Release Date': '2014-09-04',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Before_I_Go_to_Sleep_(film)',
#   'Genre': 'Mystery',
#   'Director 1': 'Rowan Joffé',
#   'Director 2': '',
#   'Cast 1': 'Nicole Kidman',
#   'Cast 2': 'Mark Strong',
#   'Cast 3': 'Colin Firth',
#   'Cast 4': 'Anne-Marie Duff',
#   'Cast 5': '',
#   'Budget': '$22,000,000.00',
#   'Revenue': '$15,100,000.00'},
#  {'Movie Title': 'Ben-Hur',
#   'Release Date': '2016-08-19',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Ben-Hur_(2016_film)',
#   'Genre': 'Adventure',
#   'Director 1': 'Timur Bekmambetov',
#   'Director 2': '',
#   'Cast 1': 'Jack Huston',
#   'Cast 2': 'Morgan Freeman',
#   'Cast 3': 'Toby Kebbell',
#   'Cast 4': 'Rodrigo Santoro',
#   'Cast 5': 'Nazanin Boniadi',
#   'Budget': '$100,000,000.00',
#   'Revenue': '$41,400,000.00'},
#  {'Movie Title': 'Beyond the Lights',
#   'Release Date': '2014-09-06',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Beyond_the_Lights',
#   'Genre': 'Romance',
#   'Director 1': 'Gina Prince-Bythewood',
#   'Director 2': '',
#   'Cast 1': 'Gugu Mbatha-Raw',
#   'Cast 2': 'Nate Parker',
#   'Cast 3': 'Minnie Driver',
#   'Cast 4': 'Danny Glover',
#   'Cast 5': '',
#   'Budget': '$7,000,000.00',
#   'Revenue': '$14,600,000.00'},
#  {'Movie Title': 'Big Eyes',
#   'Release Date': '2014-12-25',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Big_Eyes',
#   'Genre': 'Biography',
#   'Director 1': 'Tim Burton',
#   'Director 2': '',
#   'Cast 1': 'Amy Adams',
#   'Cast 2': 'Christoph Waltz',
#   'Cast 3': 'Krysten Ritter',
#   'Cast 4': 'Danny Huston',
#   'Cast 5': 'Terence Stamp',
#   'Budget': '$10,000,000.00',
#   'Revenue': '$29,300,000.00'},
#  {'Movie Title': 'Black Mass',
#   'Release Date': '2015-09-04',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Black_Mass_(film)',
#   'Genre': 'Action',
#   'Director 1': 'Scott Cooper',
#   'Director 2': '',
#   'Cast 1': 'Johnny Depp',
#   'Cast 2': 'Joel Edgerton',
#   'Cast 3': 'Benedict Cumberbatch',
#   'Cast 4': 'Sienna Miller',
#   'Cast 5': 'Dakota Johnson',
#   'Budget': '$53,000,000.00',
#   'Revenue': '$99,800,000.00'},
#  {'Movie Title': 'Blackhat',
#   'Release Date': '2015-01-08',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Blackhat_(film)',
#   'Genre': 'Action',
#   'Director 1': 'Michael Mann',
#   'Director 2': '',
#   'Cast 1': 'Chris Hemsworth',
#   'Cast 2': 'Viola Davis',
#   'Cast 3': 'John Ortiz',
#   'Cast 4': 'Yorick van Wageningen',
#   'Cast 5': 'Tang Wei',
#   'Budget': '$70,000,000.00',
#   'Revenue': '$19,700,000.00'},
#  {'Movie Title': 'Blended',
#   'Release Date': '2014-05-23',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Blended_(film)',
#   'Genre': 'Comedy',
#   'Director 1': 'Frank Coraci',
#   'Director 2': '',
#   'Cast 1': 'Adam Sandler',
#   'Cast 2': 'Drew Barrymore',
#   'Cast 3': 'Bella Thorne',
#   'Cast 4': 'Emma Fuhrmann',
#   'Cast 5': 'Terry Crews',
#   'Budget': '$40,000,000.00',
#   'Revenue': '$128,000,000.00'},
#  {'Movie Title': 'Blue Jasmine',
#   'Release Date': '2013-07-26',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Blue_Jasmine',
#   'Genre': 'Drama',
#   'Director 1': 'Woody Allen',
#   'Director 2': '',
#   'Cast 1': 'Alec Baldwin',
#   'Cast 2': 'Cate Blanchett',
#   'Cast 3': 'Bobby Cannavale',
#   'Cast 4': 'Louis C.K.',
#   'Cast 5': 'Andrew Dice Clay',
#   'Budget': '$18,000,000.00',
#   'Revenue': '$97,500,000.00'},
#  {'Movie Title': 'Boyhood',
#   'Release Date': '2014-01-19',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Boyhood_(film)',
#   'Genre': 'Drama',
#   'Director 1': 'Richard Linklater',
#   'Director 2': '',
#   'Cast 1': 'Ethan Hawke',
#   'Cast 2': 'Patricia Arquette',
#   'Cast 3': 'Ellar Coltrane',
#   'Cast 4': '',
#   'Cast 5': '',
#   'Budget': '$4,000,000.00',
#   'Revenue': '$44,500,000.00'},
#  {'Movie Title': 'Brick Mansions',
#   'Release Date': '2014-04-23',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Brick_Mansions',
#   'Genre': 'Action',
#   'Director 1': 'Camille Delamarre',
#   'Director 2': '',
#   'Cast 1': 'Paul Walker',
#   'Cast 2': 'David Belle',
#   'Cast 3': 'RZA',
#   'Cast 4': '',
#   'Cast 5': '',
#   'Budget': '$23,000,000.00',
#   'Revenue': '$69,000,000.00'},
#  {'Movie Title': 'Bridge of Spies',
#   'Release Date': '2015-10-04',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Bridge_of_Spies_(film)',
#   'Genre': 'Drama',
#   'Director 1': 'Steven Spielberg',
#   'Director 2': '',
#   'Cast 1': 'Tom Hanks',
#   'Cast 2': 'Mark Rylance',
#   'Cast 3': 'Amy Ryan',
#   'Cast 4': 'Alan Alda',
#   'Cast 5': 'Austin Stowell',
#   'Budget': '$40,000,000.00',
#   'Revenue': '$165,500,000.00'},
#  {'Movie Title': 'Brooklyn',
#   'Release Date': '2015-01-26',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Brooklyn_(film)',
#   'Genre': 'Drama',
#   'Director 1': 'John Crowley',
#   'Director 2': '',
#   'Cast 1': 'Saoirse Ronan',
#   'Cast 2': 'Emory Cohen',
#   'Cast 3': 'Domhnall Gleeson',
#   'Cast 4': 'Jim Broadbent',
#   'Cast 5': 'Julie Walters',
#   'Budget': '$11,000,000.00',
#   'Revenue': '$62,100,000.00'},
#  {'Movie Title': 'Bullet to the Head',
#   'Release Date': '2013-02-01',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Bullet_to_the_Head',
#   'Genre': 'Crime',
#   'Director 1': 'Walter Hill',
#   'Director 2': '',
#   'Cast 1': 'Sylvester Stallone',
#   'Cast 2': 'Sung Kang',
#   'Cast 3': 'Sarah Shahi',
#   'Cast 4': 'Adewale Akinnuoye-Agbaje',
#   'Cast 5': 'Religious Slater',
#   'Budget': '$55,000,000.00',
#   'Revenue': '$21,900,000.00'},
#  {'Movie Title': 'Burnt',
#   'Release Date': '2015-10-06',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Burnt_(film)',
#   'Genre': 'Comedy',
#   'Director 1': 'John Wells',
#   'Director 2': '',
#   'Cast 1': 'Bradley Cooper',
#   'Cast 2': 'Jamie Dornan',
#   'Cast 3': 'Emma Thompson',
#   'Cast 4': 'Sienna Miller',
#   'Cast 5': 'Daniel Brühl',
#   'Budget': '$20,000,000.00',
#   'Revenue': '$36,600,000.00'},
#  {'Movie Title': 'By the Sea',
#   'Release Date': '2015-11-05',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/By_the_Sea_(2015_film)',
#   'Genre': 'Drama',
#   'Director 1': 'Angelina Jolie',
#   'Director 2': '',
#   'Cast 1': 'Angelina Jolie',
#   'Cast 2': 'Brad Pitt',
#   'Cast 3': 'Mélanie Laurent',
#   'Cast 4': 'Niels Arestrup',
#   'Cast 5': 'Melvil Poupaud',
#   'Budget': '$10,000,000.00',
#   'Revenue': '$3,300,000.00'},
#  {'Movie Title': 'Captain America: The Winter Soldier',
#   'Release Date': '2014-03-13',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Captain_America:_The_Winter_Soldier',
#   'Genre': 'Action',
#   'Director 1': 'Anthony Russo',
#   'Director 2': 'Joe Russo',
#   'Cast 1': 'Chris Evans',
#   'Cast 2': 'Scarlett Johansson',
#   'Cast 3': 'Sebastian Stan',
#   'Cast 4': 'Anthony Mackie',
#   'Cast 5': 'Cobie Smulders',
#   'Budget': '$170,000,000.00',
#   'Revenue': '$714,400,000.00'},
#  {'Movie Title': 'Captive',
#   'Release Date': '2015-09-18',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Captive_(2015_film)',
#   'Genre': 'Crime',
#   'Director 1': 'Jerry Jameson',
#   'Director 2': '',
#   'Cast 1': 'David Oyelowo',
#   'Cast 2': 'Kate Mara',
#   'Cast 3': 'Michael K. Williams',
#   'Cast 4': 'Leonor Varela',
#   'Cast 5': 'Jessica Oyelowo',
#   'Budget': '$2,000,000.00',
#   'Revenue': '$2,800,000.00'},
#  {'Movie Title': 'Carol',
#   'Release Date': '2015-05-17',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Carol_(film)',
#   'Genre': 'Drama',
#   'Director 1': 'Todd Haynes',
#   'Director 2': '',
#   'Cast 1': 'Cate Blanchett',
#   'Cast 2': 'Rooney Mara',
#   'Cast 3': 'Sarah Paulson',
#   'Cast 4': 'Kyle Chandler',
#   'Cast 5': 'Jake Lacy',
#   'Budget': '$11,800,000.00',
#   'Revenue': '$40,300,000.00'},
#  {'Movie Title': 'Central Intelligence',
#   'Release Date': '2016-06-10',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Central_Intelligence',
#   'Genre': 'Action',
#   'Director 1': 'Rawson Marshall Thurber',
#   'Director 2': '',
#   'Cast 1': 'Dwayne Johnson',
#   'Cast 2': 'Kevin Hart',
#   'Cast 3': 'Amy Ryan',
#   'Cast 4': 'Aaron Paul',
#   'Cast 5': '',
#   'Budget': '$50,000,000.00',
#   'Revenue': '$212,200,000.00'},
#  {'Movie Title': 'Cesar Chavez',
#   'Release Date': '2014-02-12',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Cesar_Chavez_(film)',
#   'Genre': 'Drama',
#   'Director 1': 'Diego Luna',
#   'Director 2': '',
#   'Cast 1': 'Michael Peña',
#   'Cast 2': 'America Ferrera',
#   'Cast 3': 'Rosario Dawson',
#   'Cast 4': 'John Malkovich',
#   'Cast 5': '',
#   'Budget': '$10,000,000.00',
#   'Revenue': '$6,700,000.00'},
#  {'Movie Title': 'Chappie',
#   'Release Date': '2015-03-04',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Chappie_(film)',
#   'Genre': 'Sci-Fi',
#   'Director 1': 'Neill Blomkamp',
#   'Director 2': '',
#   'Cast 1': 'Sharlto Copley',
#   'Cast 2': 'Ninja',
#   'Cast 3': 'Yolandi Visser',
#   'Cast 4': 'Dev Patel',
#   'Cast 5': 'Hugh Jackman',
#   'Budget': '$49,000,000.00',
#   'Revenue': '$102,100,000.00'},
#  {'Movie Title': 'Chasing Mavericks',
#   'Release Date': '2012-10-26',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Chasing_Mavericks',
#   'Genre': 'Biography',
#   'Director 1': 'Curtis Hanson',
#   'Director 2': 'Michael Apted',
#   'Cast 1': 'Gerard Butler',
#   'Cast 2': 'Jonny Weston',
#   'Cast 3': 'Elisabeth Shue',
#   'Cast 4': 'Abigail Spencer',
#   'Cast 5': '',
#   'Budget': '$20,000,000.00',
#   'Revenue': '$8,300,000.00'},
#  {'Movie Title': 'Chef',
#   'Release Date': '2014-03-07',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Chef_(film)',
#   'Genre': 'Comedy',
#   'Director 1': 'Jon Favreau',
#   'Director 2': '',
#   'Cast 1': 'Jon Favreau',
#   'Cast 2': 'Sofía Vergara',
#   'Cast 3': 'Scarlett Johansson',
#   'Cast 4': 'John Leguizamo',
#   'Cast 5': 'Robert Downey',
#   'Budget': '$11,000,000.00',
#   'Revenue': '$46,000,000.00'},
#  {'Movie Title': 'Chernobyl Diaries',
#   'Release Date': '2012-05-25',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Chernobyl_Diaries',
#   'Genre': 'Horror',
#   'Director 1': 'Bradley Parker',
#   'Director 2': '',
#   'Cast 1': 'Jonathan Sadowski',
#   'Cast 2': 'Devin Kelley',
#   'Cast 3': 'Jesse McCartney',
#   'Cast 4': 'Olivia Taylor Dudley',
#   'Cast 5': 'Nathan Phillips',
#   'Budget': '$1,000,000.00',
#   'Revenue': '$37,200,000.00'},
#  {'Movie Title': 'Child 44',
#   'Release Date': '2015-04-17',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Child_44_(film)',
#   'Genre': 'Drama',
#   'Director 1': 'Daniel Espinosa',
#   'Director 2': '',
#   'Cast 1': 'Tom Hardy',
#   'Cast 2': 'Gary Oldman',
#   'Cast 3': 'Joel Kinnaman',
#   'Cast 4': 'Noomi Rapace',
#   'Cast 5': 'Jason Clarke',
#   'Budget': '$50,000,000.00',
#   'Revenue': '$13,000,000.00'},
#  {'Movie Title': 'Chronicle',
#   'Release Date': '2012-02-03',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Chronicle_(film)',
#   'Genre': 'Sci-Fi',
#   'Director 1': 'Josh Trank',
#   'Director 2': '',
#   'Cast 1': 'Dane DeHaan',
#   'Cast 2': 'Michael B. Jordan',
#   'Cast 3': 'Alex Russell',
#   'Cast 4': 'Michael Kelly',
#   'Cast 5': '',
#   'Budget': '$12,000,000.00',
#   'Revenue': '$126,600,000.00'},
#  {'Movie Title': 'Cloud Atlas',
#   'Release Date': '2012-10-26',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Cloud_Atlas_(film)',
#   'Genre': 'Drama',
#   'Director 1': 'Tom Tykwer',
#   'Director 2': 'Andy Wachowski',
#   'Cast 1': 'Tom Hanks',
#   'Cast 2': 'Jim Sturgess',
#   'Cast 3': 'David Gyasi',
#   'Cast 4': 'Jim Broadbent',
#   'Cast 5': 'Ben Whishaw',
#   'Budget': '$128,500,000.00',
#   'Revenue': '$130,500,000.00'},
#  {'Movie Title': 'Cloudy with a Chance of Meatballs 2',
#   'Release Date': '2013-09-27',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Cloudy_with_a_Chance_of_Meatballs_2',
#   'Genre': 'Family',
#   'Director 1': 'Cody Cameron',
#   'Director 2': 'Kris Pearn',
#   'Cast 1': 'Anna Faris',
#   'Cast 2': 'Bill Hader',
#   'Cast 3': 'Andy Samberg',
#   'Cast 4': 'Kristen Schaal',
#   'Cast 5': 'James Caan',
#   'Budget': '$78,000,000.00',
#   'Revenue': '$274,300,000.00'},
#  {'Movie Title': 'Concussion',
#   'Release Date': '2015-12-25',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Concussion_(2015_film)',
#   'Genre': 'Drama',
#   'Director 1': 'Peter Landesman',
#   'Director 2': '',
#   'Cast 1': 'Will Smith',
#   'Cast 2': 'Alec Baldwin',
#   'Cast 3': 'Gugu Mbatha-Raw',
#   'Cast 4': 'Albert Brooks',
#   'Cast 5': 'Paul Reiser',
#   'Budget': '$57,000,000.00',
#   'Revenue': '$50,300,000.00'},
#  {'Movie Title': 'Creed',
#   'Release Date': '2015-11-25',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Creed_(film)',
#   'Genre': 'Drama',
#   'Director 1': 'Ryan Coogler',
#   'Director 2': '',
#   'Cast 1': 'Michael B. Jordan',
#   'Cast 2': 'Sylvester Stallone',
#   'Cast 3': 'Tessa Thompson',
#   'Cast 4': 'Graham McTavish',
#   'Cast 5': 'Tony Bellew',
#   'Budget': '$40,000,000.00',
#   'Revenue': '$173,600,000.00'},
#  {'Movie Title': 'Criminal',
#   'Release Date': '2016-04-15',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Criminal_(2016_film)',
#   'Genre': 'Action',
#   'Director 1': 'Ariel Vromen',
#   'Director 2': '',
#   'Cast 1': 'Kevin Costner',
#   'Cast 2': 'Gary Oldman',
#   'Cast 3': 'Tommy Lee Jones',
#   'Cast 4': 'Alice Eve',
#   'Cast 5': 'Gal Gadot',
#   'Budget': '$31,500,000.00',
#   'Revenue': '$35,600,000.00'},
#  {'Movie Title': 'Crimson Peak',
#   'Release Date': '2015-10-16',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Crimson_Peak',
#   'Genre': 'Horror',
#   'Director 1': 'Guillermo del Toro',
#   'Director 2': '',
#   'Cast 1': 'Mia Wasikowska',
#   'Cast 2': 'Tom Hiddleston',
#   'Cast 3': 'Charlie Hunnam',
#   'Cast 4': 'Jessica Chastain',
#   'Cast 5': 'Jim Beaver',
#   'Budget': '$55,000,000.00',
#   'Revenue': '$74,700,000.00'},
#  {'Movie Title': "Daddy's Home",
#   'Release Date': '2015-12-25',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Daddy%2527s_Home_(film)',
#   'Genre': 'Comedy',
#   'Director 1': 'Sean Anders',
#   'Director 2': 'John Morris',
#   'Cast 1': 'Will Ferrell',
#   'Cast 2': 'Mark Wahlberg',
#   'Cast 3': 'Linda Cardellini',
#   'Cast 4': '',
#   'Cast 5': '',
#   'Budget': '$69,000,000.00',
#   'Revenue': '$240,400,000.00'},
#  {'Movie Title': 'Danny Collins',
#   'Release Date': '2015-03-20',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Danny_Collins_(film)',
#   'Genre': 'Comedy',
#   'Director 1': 'Dan Fogelman',
#   'Director 2': '',
#   'Cast 1': 'Al Pacino',
#   'Cast 2': 'Annette Bening',
#   'Cast 3': 'Jennifer Garner',
#   'Cast 4': 'Bobby Cannavale',
#   'Cast 5': 'Christopher Plummer',
#   'Budget': '$10,000,000.00',
#   'Revenue': '$8,200,000.00'},
#  {'Movie Title': 'Dark Shadows',
#   'Release Date': '2012-05-11',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Dark_Shadows_(film)',
#   'Genre': 'Comedy',
#   'Director 1': 'Tim Burton',
#   'Director 2': '',
#   'Cast 1': 'Johnny Depp',
#   'Cast 2': 'Michelle Pfeiffer',
#   'Cast 3': 'Helena Bonham Carter',
#   'Cast 4': 'Eva Green',
#   'Cast 5': 'Jackie Earle Haley',
#   'Budget': '$150,000,000.00',
#   'Revenue': '$245,500,000.00'},
#  {'Movie Title': 'Dark Skies',
#   'Release Date': '2013-02-22',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Dark_Skies_(film)',
#   'Genre': 'Horror',
#   'Director 1': 'Scott Charles Stewart',
#   'Director 2': '',
#   'Cast 1': 'Keri Russell',
#   'Cast 2': 'Josh Hamilton',
#   'Cast 3': 'Dakota Goyo',
#   'Cast 4': '',
#   'Cast 5': '',
#   'Budget': '$3,500,000.00',
#   'Revenue': '$26,400,000.00'},
#  {'Movie Title': 'Dawn of the Planet of the Apes',
#   'Release Date': '2014-06-26',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Dawn_of_the_Planet_of_the_Apes',
#   'Genre': 'Action',
#   'Director 1': 'Matt Reeves',
#   'Director 2': '',
#   'Cast 1': 'Andy Serkis',
#   'Cast 2': 'Gary Oldman',
#   'Cast 3': 'Jason Clarke',
#   'Cast 4': 'Kodi Smit-McPhee',
#   'Cast 5': 'Keri Russell',
#   'Budget': '$235,000,000.00',
#   'Revenue': '$710,600,000.00'},
#  {'Movie Title': 'Dead Man Down',
#   'Release Date': '2013-03-08',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Dead_Man_Down',
#   'Genre': 'Action',
#   'Director 1': 'Niels Arden Oplev',
#   'Director 2': '',
#   'Cast 1': 'Colin Farrell',
#   'Cast 2': 'Noomi Rapace',
#   'Cast 3': 'Dominic Cooper',
#   'Cast 4': 'Terrence Howard',
#   'Cast 5': 'Wade Barrett',
#   'Budget': '$30,000,000.00',
#   'Revenue': '$18,100,000.00'},
#  {'Movie Title': 'Deadpool',
#   'Release Date': '2016-02-08',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Deadpool_(film)',
#   'Genre': 'Action',
#   'Director 1': 'Tim Miller',
#   'Director 2': '',
#   'Cast 1': 'Ryan Reynolds',
#   'Cast 2': 'Gina Carano',
#   'Cast 3': 'T. J. Miller',
#   'Cast 4': 'Ed Skrein',
#   'Cast 5': 'Morena Baccarin',
#   'Budget': '$58,000,000.00',
#   'Revenue': '$782,600,000.00'},
#  {'Movie Title': 'Declaration of War',
#   'Release Date': '2012-01-27',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Declaration_of_War_(film)',
#   'Genre': 'Romance',
#   'Director 1': 'Valérie Donzelli',
#   'Director 2': '',
#   'Cast 1': 'Valérie Donzelli (director)',
#   'Cast 2': '',
#   'Cast 3': '',
#   'Cast 4': '',
#   'Cast 5': '',
#   'Budget': '$1,500,000.00',
#   'Revenue': '$6,500,000.00'},
#  {'Movie Title': 'Deliver Us from Evil',
#   'Release Date': '2014-07-02',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Deliver_Us_from_Evil_(2014_film)',
#   'Genre': 'Horror',
#   'Director 1': 'Scott Derrickson',
#   'Director 2': 'Paul Harris',
#   'Cast 1': 'Eric Bana',
#   'Cast 2': 'Édgar Ramírez',
#   'Cast 3': 'Olivia Munn',
#   'Cast 4': 'Joel McHale',
#   'Cast 5': '',
#   'Budget': '$30,000,000.00',
#   'Revenue': '$87,900,000.00'},
#  {'Movie Title': 'Despicable Me 2',
#   'Release Date': '2013-06-20',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Despicable_Me_2',
#   'Genre': 'Comedy',
#   'Director 1': 'Chris Renaud',
#   'Director 2': 'Pierre Coffin',
#   'Cast 1': 'Steve Carell',
#   'Cast 2': 'Kristen Wiig',
#   'Cast 3': 'Miranda Cosgrove',
#   'Cast 4': 'Dana Gaier',
#   'Cast 5': 'Elsie Fisher',
#   'Budget': '$76,000,000.00',
#   'Revenue': '$970,800,000.00'},
#  {'Movie Title': "Devil's Due",
#   'Release Date': '2014-01-17',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Devil%2527s_Due_(film)',
#   'Genre': 'Horror',
#   'Director 1': 'Matt Bettinelli-Olpin',
#   'Director 2': 'Tyler Gillett',
#   'Cast 1': 'Allison Miller',
#   'Cast 2': 'Zach Gilford',
#   'Cast 3': 'Sam Anderson',
#   'Cast 4': 'Aimee Carrero',
#   'Cast 5': 'Vanessa Ray',
#   'Budget': '$7,000,000.00',
#   'Revenue': '$36,900,000.00'},
#  {'Movie Title': 'Diary of a Wimpy Kid: Dog Days',
#   'Release Date': '2012-08-03',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Diary_of_a_Wimpy_Kid:_Dog_Days_(film)',
#   'Genre': 'Comedy',
#   'Director 1': 'David Bowers',
#   'Director 2': '',
#   'Cast 1': 'Zachary Gordon',
#   'Cast 2': 'Robert Capron',
#   'Cast 3': 'Rachael Harris',
#   'Cast 4': 'Devon Bostick',
#   'Cast 5': 'Steve Zahn',
#   'Budget': '$22,000,000.00',
#   'Revenue': '$77,100,000.00'},
#  {'Movie Title': 'Divergent',
#   'Release Date': '2014-03-18',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Divergent_(film)',
#   'Genre': 'Sci-Fi',
#   'Director 1': 'Neil Burger',
#   'Director 2': '',
#   'Cast 1': 'Shailene Woodley',
#   'Cast 2': 'Kate Winslet',
#   'Cast 3': 'Theo James',
#   'Cast 4': 'Ansel Elgort',
#   'Cast 5': 'Zoë Kravitz',
#   'Budget': '$85,000,000.00',
#   'Revenue': '$288,900,000.00'},
#  {'Movie Title': 'Django Unchained',
#   'Release Date': '2012-12-25',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Django_Unchained',
#   'Genre': 'Action',
#   'Director 1': 'Quentin Tarantino',
#   'Director 2': '',
#   'Cast 1': 'Christoph Waltz',
#   'Cast 2': 'Jamie Foxx',
#   'Cast 3': 'Leonardo DiCaprio',
#   'Cast 4': 'Samuel L. Jackson',
#   'Cast 5': 'Bruce Dern',
#   'Budget': '$100,000,000.00',
#   'Revenue': '$425,400,000.00'},
#  {'Movie Title': 'Dolphin Tale 2',
#   'Release Date': '2014-09-12',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Dolphin_Tale_2',
#   'Genre': 'Family',
#   'Director 1': 'Charles Martin Smith',
#   'Director 2': '',
#   'Cast 1': 'Winter',
#   'Cast 2': 'Hope',
#   'Cast 3': 'Nathan Gamble',
#   'Cast 4': 'Harry Connick',
#   'Cast 5': 'Jr.',
#   'Budget': '$36,000,000.00',
#   'Revenue': '$57,800,000.00'},
#  {'Movie Title': "Don't Breathe",
#   'Release Date': '2016-08-26',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Don%2527t_Breathe_(2016_film)',
#   'Genre': 'Thriller',
#   'Director 1': 'Fede Alvarez',
#   'Director 2': '',
#   'Cast 1': 'Dylan Minnette',
#   'Cast 2': 'Stephen Lang',
#   'Cast 3': 'Daniel Zovatto',
#   'Cast 4': '',
#   'Cast 5': '',
#   'Budget': '$9,900,000.00',
#   'Revenue': '$28,300,000.00'},
#  {'Movie Title': "Dr. Seuss' The Lorax",
#   'Release Date': '2012-03-02',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/The_Lorax_(film)',
#   'Genre': 'Family',
#   'Director 1': 'Chris Renaud',
#   'Director 2': '',
#   'Cast 1': 'Danny DeVito',
#   'Cast 2': 'Zac Efron',
#   'Cast 3': 'Taylor Swift',
#   'Cast 4': 'Ed Helms',
#   'Cast 5': 'Rob Riggle',
#   'Budget': '$70,000,000.00',
#   'Revenue': '$348,800,000.00'},
#  {'Movie Title': 'Dracula Untold',
#   'Release Date': '2014-10-10',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Dracula_Untold',
#   'Genre': 'Drama',
#   'Director 1': 'Gary Shore',
#   'Director 2': '',
#   'Cast 1': 'Luke Evans',
#   'Cast 2': 'Sarah Gadon',
#   'Cast 3': 'William Houston',
#   'Cast 4': 'Dominic Cooper',
#   'Cast 5': 'Samantha Barks',
#   'Budget': '$70,000,000.00',
#   'Revenue': '$217,100,000.00'},
#  {'Movie Title': 'Draft Day',
#   'Release Date': '2014-04-07',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Draft_Day',
#   'Genre': 'Drama',
#   'Director 1': 'Ivan Reitman',
#   'Director 2': '',
#   'Cast 1': 'Kevin Costner',
#   'Cast 2': 'Jennifer Garner',
#   'Cast 3': 'Denis Leary',
#   'Cast 4': 'Frank Langella',
#   'Cast 5': 'Tom Welling',
#   'Budget': '$25,000,000.00',
#   'Revenue': '$29,500,000.00'},
#  {'Movie Title': 'Dragon Blade',
#   'Release Date': '2015-02-18',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Dragon_Blade_(film)',
#   'Genre': 'Action',
#   'Director 1': 'Daniel Lee',
#   'Director 2': '',
#   'Cast 1': 'Jackie Chan',
#   'Cast 2': 'Choi Siwon',
#   'Cast 3': 'John Cusack',
#   'Cast 4': 'Adrien Brody',
#   'Cast 5': 'James Lee Guy',
#   'Budget': '$65,000,000.00',
#   'Revenue': '$120,000,000.00'},
#  {'Movie Title': 'Dumb and Dumber To',
#   'Release Date': '2014-11-14',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Dumb_and_Dumber_To',
#   'Genre': 'Comedy',
#   'Director 1': 'Peter Farrelly',
#   'Director 2': 'Bobby Farrelly',
#   'Cast 1': 'Jim Carrey',
#   'Cast 2': 'Jeff Daniels',
#   'Cast 3': 'Kathleen Turner',
#   'Cast 4': 'Laurie Holden',
#   'Cast 5': '',
#   'Budget': '$50,000,000.00',
#   'Revenue': '$169,800,000.00'},
#  {'Movie Title': 'Earth to Echo',
#   'Release Date': '2014-06-14',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Earth_to_Echo',
#   'Genre': 'Sci-Fi',
#   'Director 1': 'Dave Green',
#   'Director 2': '',
#   'Cast 1': 'Astro',
#   'Cast 2': 'Teo Halm',
#   'Cast 3': 'Reese Hartwig',
#   'Cast 4': 'Ella Wahlestedt',
#   'Cast 5': '',
#   'Budget': '$13,000,000.00',
#   'Revenue': '$45,300,000.00'},
#  {'Movie Title': 'Eddie the Eagle',
#   'Release Date': '2016-02-26',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Eddie_the_Eagle_(film)',
#   'Genre': 'Drama',
#   'Director 1': 'Dexter Fletcher',
#   'Director 2': '',
#   'Cast 1': 'Taron Egerton',
#   'Cast 2': 'Christopher Walken',
#   'Cast 3': 'Hugh Jackman',
#   'Cast 4': '',
#   'Cast 5': '',
#   'Budget': '$23,000,000.00',
#   'Revenue': '$46,200,000.00'},
#  {'Movie Title': 'Edge of Tomorrow',
#   'Release Date': '2014-05-28',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Edge_of_Tomorrow_(film)',
#   'Genre': 'Action',
#   'Director 1': 'Doug Liman',
#   'Director 2': '',
#   'Cast 1': 'Tom Cruise',
#   'Cast 2': 'Emily Blunt',
#   'Cast 3': '',
#   'Cast 4': '',
#   'Cast 5': '',
#   'Budget': '$178,000,000.00',
#   'Revenue': '$370,500,000.00'},
#  {'Movie Title': 'Elysium',
#   'Release Date': '2013-08-09',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Elysium_(film)',
#   'Genre': 'Sci-Fi',
#   'Director 1': 'Neill Blomkamp',
#   'Director 2': '',
#   'Cast 1': 'Matt Damon',
#   'Cast 2': 'Jodie Foster',
#   'Cast 3': 'Sharlto Copley',
#   'Cast 4': 'Wagner Moura',
#   'Cast 5': 'Alice Braga',
#   'Budget': '$115,000,000.00',
#   'Revenue': '$286,100,000.00'},
#  {'Movie Title': 'Embrace of the Serpent',
#   'Release Date': '2015-05-15',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Embrace_of_the_Serpent',
#   'Genre': 'Adventure',
#   'Director 1': 'Ciro Guerra',
#   'Director 2': '',
#   'Cast 1': 'Jan Bijvoet',
#   'Cast 2': 'Nilbio Torres',
#   'Cast 3': 'Antonio Bolívar',
#   'Cast 4': '',
#   'Cast 5': '',
#   'Budget': '$1,400,000.00',
#   'Revenue': '$2,800,000.00'},
#  {'Movie Title': 'End of Watch',
#   'Release Date': '2012-09-21',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/End_of_Watch',
#   'Genre': 'Action',
#   'Director 1': 'David Ayer',
#   'Director 2': '',
#   'Cast 1': 'Jake Gyllenhaal',
#   'Cast 2': 'Michael Peña',
#   'Cast 3': 'Anna Kendrick',
#   'Cast 4': 'Frank Grillo',
#   'Cast 5': 'America Ferrera',
#   'Budget': '$7,000,000.00',
#   'Revenue': '$48,100,000.00'},
#  {'Movie Title': 'Enough Said',
#   'Release Date': '2013-09-20',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Enough_Said_(film)',
#   'Genre': 'Comedy',
#   'Director 1': 'Nicole Holofcener',
#   'Director 2': '',
#   'Cast 1': 'James Gandolfini',
#   'Cast 2': 'Julia Louis-Dreyfus',
#   'Cast 3': 'Toni Collette',
#   'Cast 4': 'Catherine Keener',
#   'Cast 5': 'Ben Falcone',
#   'Budget': '$8,000,000.00',
#   'Revenue': '$25,300,000.00'},
#  {'Movie Title': 'Entourage',
#   'Release Date': '2015-05-27',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Entourage_(film)',
#   'Genre': 'Comedy',
#   'Director 1': 'Doug Ellin',
#   'Director 2': '',
#   'Cast 1': 'Adrian Grenier',
#   'Cast 2': 'Kevin Connolly',
#   'Cast 3': 'Kevin Dillon',
#   'Cast 4': 'Jerry Ferrara',
#   'Cast 5': 'Jeremy Piven',
#   'Budget': '$39,000,000.00',
#   'Revenue': '$49,300,000.00'},
#  {'Movie Title': 'Epic',
#   'Release Date': '2013-05-24',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Epic_(2013_film)',
#   'Genre': 'Adventure',
#   'Director 1': 'Chris Wedge',
#   'Director 2': '',
#   'Cast 1': 'Colin Farrell',
#   'Cast 2': 'Josh Hutcherson',
#   'Cast 3': 'Amanda Seyfried',
#   'Cast 4': 'Jason Sudeikis',
#   'Cast 5': 'Christoph Waltz',
#   'Budget': '$93,000,000.00',
#   'Revenue': '$268,400,000.00'},
#  {'Movie Title': 'Escape from Planet Earth',
#   'Release Date': '2013-02-15',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Escape_from_Planet_Earth',
#   'Genre': 'Comedy',
#   'Director 1': 'Cal Brunker',
#   'Director 2': '',
#   'Cast 1': 'Brendan Fraser',
#   'Cast 2': 'Rob Corddry',
#   'Cast 3': 'Jessica Alba',
#   'Cast 4': 'William Shatner',
#   'Cast 5': 'Sarah Jessica Parker',
#   'Budget': '$40,000,000.00',
#   'Revenue': '$74,600,000.00'},
#  {'Movie Title': 'Evil Dead',
#   'Release Date': '2013-04-05',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Evil_Dead_(2013_film)',
#   'Genre': 'Horror',
#   'Director 1': 'Fede Alvarez',
#   'Director 2': '',
#   'Cast 1': 'Jane Levy',
#   'Cast 2': 'Shiloh Fernandez',
#   'Cast 3': 'Lou Taylor Pucci',
#   'Cast 4': 'Jessica Lucas',
#   'Cast 5': 'Elizabeth Blackmore',
#   'Budget': '$17,000,000.00',
#   'Revenue': '$97,500,000.00'},
#  {'Movie Title': 'Ex Machina',
#   'Release Date': '2015-01-21',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Ex_Machina_(film)',
#   'Genre': 'Sci-Fi',
#   'Director 1': 'Alex Garland',
#   'Director 2': '',
#   'Cast 1': 'Domhnall Gleeson',
#   'Cast 2': 'Oscar Isaac',
#   'Cast 3': 'Alicia Vikander',
#   'Cast 4': '',
#   'Cast 5': '',
#   'Budget': '$15,000,000.00',
#   'Revenue': '$36,900,000.00'},
#  {'Movie Title': 'Eye in the Sky',
#   'Release Date': '2015-09-11',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Eye_in_the_Sky_(2015_film)',
#   'Genre': 'Thriller',
#   'Director 1': 'Gavin Hood',
#   'Director 2': '',
#   'Cast 1': 'Helen Mirren',
#   'Cast 2': 'Aaron Paul',
#   'Cast 3': 'Alan Rickman',
#   'Cast 4': 'Barkhad Abdi',
#   'Cast 5': '',
#   'Budget': '$13,000,000.00',
#   'Revenue': '$32,800,000.00'},
#  {'Movie Title': 'Fantastic Four',
#   'Release Date': '2015-08-04',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Fantastic_Four_(2015_film)',
#   'Genre': 'Action',
#   'Director 1': 'Josh Trank',
#   'Director 2': '',
#   'Cast 1': 'Miles Teller',
#   'Cast 2': 'Michael B. Jordan',
#   'Cast 3': 'Kate Mara',
#   'Cast 4': 'Jamie Bell',
#   'Cast 5': 'Toby Kebbell',
#   'Budget': '$120,000,000.00',
#   'Revenue': '$168,000,000.00'},
#  {'Movie Title': 'Fast & Furious 6',
#   'Release Date': '2013-05-17',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Fast_%2526_Furious_6',
#   'Genre': 'Action',
#   'Director 1': 'Justin Lin',
#   'Director 2': '',
#   'Cast 1': 'Vin Diesel',
#   'Cast 2': 'Dwayne Johnson',
#   'Cast 3': 'Paul Walker',
#   'Cast 4': 'Michelle Rodriguez',
#   'Cast 5': 'Jordana Brewster',
#   'Budget': '$160,000,000.00',
#   'Revenue': '$788,700,000.00'},
#  {'Movie Title': 'Flight',
#   'Release Date': '2012-11-02',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Flight_(2012_film)',
#   'Genre': 'Drama',
#   'Director 1': 'Robert Zemeckis',
#   'Director 2': '',
#   'Cast 1': 'Denzel Washington',
#   'Cast 2': 'Brian Geraghty',
#   'Cast 3': 'Nadine Velazquez',
#   'Cast 4': 'Bruce Greenwood',
#   'Cast 5': 'John Goodman',
#   'Budget': '$31,000,000.00',
#   'Revenue': '$161,800,000.00'},
#  {'Movie Title': 'Florence Foster Jenkins',
#   'Release Date': '2016-04-27',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Florence_Foster_Jenkins_(film)',
#   'Genre': 'Biography',
#   'Director 1': 'Stephen Frears',
#   'Director 2': '',
#   'Cast 1': 'Meryl Streep',
#   'Cast 2': 'Hugh Grant',
#   'Cast 3': 'Simon Helberg',
#   'Cast 4': 'Nina Arianda',
#   'Cast 5': 'Rebecca Ferguson',
#   'Budget': '$19,000,000.00',
#   'Revenue': '$31,700,000.00'},
#  {'Movie Title': 'Frances Ha',
#   'Release Date': '2013-05-17',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Frances_Ha',
#   'Genre': 'Drama',
#   'Director 1': 'Noah Baumbach',
#   'Director 2': '',
#   'Cast 1': 'Greta Gerwig',
#   'Cast 2': "Charlotte d'Amboise",
#   'Cast 3': 'Adam Driver',
#   'Cast 4': 'Grace Gummer',
#   'Cast 5': 'Patrick Heusinger',
#   'Budget': '$3,000,000.00',
#   'Revenue': '$11,300,000.00'},
#  {'Movie Title': 'Free State of Jones',
#   'Release Date': '2016-06-16',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Free_State_of_Jones_(film)',
#   'Genre': 'Drama',
#   'Director 1': 'Gary Ross',
#   'Director 2': '',
#   'Cast 1': 'Matthew McConaughey',
#   'Cast 2': 'Gugu Mbatha-Raw',
#   'Cast 3': 'Keri Russell',
#   'Cast 4': 'Mahershala Ali',
#   'Cast 5': '',
#   'Budget': '$50,000,000.00',
#   'Revenue': '$21,200,000.00'},
#  {'Movie Title': 'Friends with Kids',
#   'Release Date': '2012-03-09',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Friends_with_Kids',
#   'Genre': 'Comedy',
#   'Director 1': 'Jennifer Westfeldt',
#   'Director 2': '',
#   'Cast 1': 'Adam Scott',
#   'Cast 2': 'Jennifer Westfeldt',
#   'Cast 3': 'Jon Hamm',
#   'Cast 4': 'Kristen Wiig',
#   'Cast 5': 'Maya Rudolph',
#   'Budget': '$10,000,000.00',
#   'Revenue': '$12,200,000.00'},
#  {'Movie Title': 'Fun Size',
#   'Release Date': '2012-10-26',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Fun_Size',
#   'Genre': 'Comedy',
#   'Director 1': 'Josh Schwartz',
#   'Director 2': '',
#   'Cast 1': 'Victoria Justice',
#   'Cast 2': 'Jane Levy',
#   'Cast 3': 'Thomas McDonell',
#   'Cast 4': 'Thomas Mann',
#   'Cast 5': 'Chelsea Handler',
#   'Budget': '$14,000,000.00',
#   'Revenue': '$11,400,000.00'},
#  {'Movie Title': 'Fury',
#   'Release Date': '2014-10-15',
# ...
#   'Budget': '$100,000,000.00',
#   'Revenue': '$103,000,000.00'},
#  {'Movie Title': 'Triple 9',
#   'Release Date': '2016-02-16',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Triple_9',
#   'Genre': 'Crime',
#   'Director 1': 'John Hillcoat',
#   'Director 2': '',
#   'Cast 1': 'Kate Winslet',
#   'Cast 2': 'Woody Harrelson',
#   'Cast 3': 'Gal Gadot',
#   'Cast 4': 'Anthony Mackie',
#   'Cast 5': 'Teresa Palmer',
#   'Budget': '$20,000,000.00',
#   'Revenue': '$23,400,000.00'},
#  {'Movie Title': 'Trouble with the Curve',
#   'Release Date': '2012-09-21',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Trouble_with_the_Curve',
#   'Genre': 'Drama',
#   'Director 1': 'Robert Lorenz',
#   'Director 2': '',
#   'Cast 1': 'Clint Eastwood',
#   'Cast 2': 'Amy Adams',
#   'Cast 3': 'Matthew Lillard',
#   'Cast 4': 'Justin Timberlake',
#   'Cast 5': 'John Goodman',
#   'Budget': '$60,000,000.00',
#   'Revenue': '$49,000,000.00'},
#  {'Movie Title': 'Trumbo',
#   'Release Date': '2015-09-12',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Trumbo_(2015_film)',
#   'Genre': 'Drama',
#   'Director 1': 'Jay Roach',
#   'Director 2': '',
#   'Cast 1': 'Bryan Cranston',
#   'Cast 2': 'Diane Lane',
#   'Cast 3': 'Helen Mirren',
#   'Cast 4': 'John Goodman',
#   'Cast 5': 'Elle Fanning',
#   'Budget': '$15,000,000.00',
#   'Revenue': '$8,200,000.00'},
#  {'Movie Title': 'Truth',
#   'Release Date': '2015-09-12',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Truth_(2015_film)',
#   'Genre': 'Drama',
#   'Director 1': 'James Vanderbilt',
#   'Director 2': '',
#   'Cast 1': 'Robert Redford',
#   'Cast 2': 'Cate Blanchett',
#   'Cast 3': 'Dennis Quaid',
#   'Cast 4': 'Topher Grace',
#   'Cast 5': 'Elisabeth Moss',
#   'Budget': '$9,600,000.00',
#   'Revenue': '$5,400,000.00'},
#  {'Movie Title': 'Turbo',
#   'Release Date': '2013-07-17',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Turbo_(film)',
#   'Genre': 'Comedy',
#   'Director 1': 'David Soren',
#   'Director 2': '',
#   'Cast 1': 'Ryan Reynolds',
#   'Cast 2': 'Paul Giamatti',
#   'Cast 3': 'Michael Peña',
#   'Cast 4': 'Luis Guzmán',
#   'Cast 5': 'Bill Hader',
#   'Budget': '$127,000,000.00',
#   'Revenue': '$282,600,000.00'},
#  {'Movie Title': 'Tusk',
#   'Release Date': '2014-09-06',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Tusk_(2014_film)',
#   'Genre': 'Horror',
#   'Director 1': 'Kevin Smith',
#   'Director 2': '',
#   'Cast 1': 'Michael Parks',
#   'Cast 2': 'Justin Long',
#   'Cast 3': 'Haley Joel Osment',
#   'Cast 4': 'Génesis Rodríguez',
#   'Cast 5': 'Johnny Depp',
#   'Budget': '$3,000,000.00',
#   'Revenue': '$1,900,000.00'},
#  {'Movie Title': 'Unbroken',
#   'Release Date': '2014-11-17',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Unbroken_(film)',
#   'Genre': 'Drama',
#   'Director 1': 'Angelina Jolie',
#   'Director 2': '',
#   'Cast 1': "Jack O'Connell",
#   'Cast 2': 'Miyavi',
#   'Cast 3': 'Domhnall Gleeson',
#   'Cast 4': 'Garrett Hedlund',
#   'Cast 5': 'Jai Courtney',
#   'Budget': '$65,000,000.00',
#   'Revenue': '$163,400,000.00'},
#  {'Movie Title': 'Unfinished Business',
#   'Release Date': '2015-03-06',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Unfinished_Business_(2015_film)',
#   'Genre': 'Comedy',
#   'Director 1': 'Ken Scott',
#   'Director 2': '',
#   'Cast 1': 'Vince Vaughn',
#   'Cast 2': 'Tom Wilkinson',
#   'Cast 3': 'Dave Franco',
#   'Cast 4': 'Sienna Miller',
#   'Cast 5': 'Nick Frost',
#   'Budget': '$35,000,000.00',
#   'Revenue': '$14,400,000.00'},
#  {'Movie Title': 'Unfriended',
#   'Release Date': '2014-07-20',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Unfriended',
#   'Genre': 'Horror',
#   'Director 1': 'Levan Gabriadze',
#   'Director 2': '',
#   'Cast 1': 'Shelley Hennig',
#   'Cast 2': 'Renee Olstead',
#   'Cast 3': 'Jacob Wysocki',
#   'Cast 4': 'Will Peltz',
#   'Cast 5': '',
#   'Budget': '$1,000,000.00',
#   'Revenue': '$64,100,000.00'},
#  {'Movie Title': 'Vacation',
#   'Release Date': '2015-07-29',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Vacation_(2015_film)',
#   'Genre': 'Adventure',
#   'Director 1': 'John Francis Daley',
#   'Director 2': 'Jonathan Goldstein',
#   'Cast 1': 'Ed Helms',
#   'Cast 2': 'Christina Applegate',
#   'Cast 3': 'Leslie Mann',
#   'Cast 4': 'Chris Hemsworth',
#   'Cast 5': 'Charlie Day',
#   'Budget': '$31,000,000.00',
#   'Revenue': '$104,900,000.00'},
#  {'Movie Title': 'Vampire Academy',
#   'Release Date': '2014-02-07',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Vampire_Academy_(film)',
#   'Genre': 'Action',
#   'Director 1': 'Mark Waters',
#   'Director 2': '',
#   'Cast 1': 'Zoey Deutch',
#   'Cast 2': 'Lucy Fry',
#   'Cast 3': 'Danila Kozlovsky',
#   'Cast 4': '',
#   'Cast 5': '',
#   'Budget': '$30,000,000.00',
#   'Revenue': '$15,400,000.00'},
#  {'Movie Title': 'Veronica Mars',
#   'Release Date': '2014-03-14',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Veronica_Mars_(film)',
#   'Genre': 'Mystery',
#   'Director 1': 'Rob Thomas',
#   'Director 2': '',
#   'Cast 1': 'Kristen Bell',
#   'Cast 2': 'Jason Dohring',
#   'Cast 3': 'Krysten Ritter',
#   'Cast 4': 'Ryan Hansen',
#   'Cast 5': 'Francis Capra',
#   'Budget': '$6,000,000.00',
#   'Revenue': '$3,500,000.00'},
#  {'Movie Title': 'Victor Frankenstein',
#   'Release Date': '2015-11-25',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Victor_Frankenstein_(film)',
#   'Genre': 'Horror',
#   'Director 1': 'Paul McGuigan',
#   'Director 2': '',
#   'Cast 1': 'Daniel Radcliffe',
#   'Cast 2': 'James McAvoy',
#   'Cast 3': 'Jessica Brown Findlay',
#   'Cast 4': 'Andrew Scott',
#   'Cast 5': '',
#   'Budget': '$40,000,000.00',
#   'Revenue': '$34,200,000.00'},
#  {'Movie Title': 'Wanderlust',
#   'Release Date': '2012-02-24',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Wanderlust_(2012_film)',
#   'Genre': 'Comedy',
#   'Director 1': 'David Wain',
#   'Director 2': '',
#   'Cast 1': 'Paul Rudd',
#   'Cast 2': 'Jennifer Aniston',
#   'Cast 3': 'Malin Akerman',
#   'Cast 4': 'Justin Theroux',
#   'Cast 5': 'Ken Marino',
#   'Budget': '$35,000,000.00',
#   'Revenue': '$24,200,000.00'},
#  {'Movie Title': 'War Dogs',
#   'Release Date': '2016-08-19',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/War_Dogs_(2016_film)',
#   'Genre': 'Crime',
#   'Director 1': 'Todd Phillips',
#   'Director 2': '',
#   'Cast 1': 'Jonah Hill',
#   'Cast 2': 'Miles Teller',
#   'Cast 3': 'Ana de Armas',
#   'Cast 4': 'J. B. Blanc',
#   'Cast 5': '',
#   'Budget': '$40,000,000.00',
#   'Revenue': '$42,700,000.00'},
#  {'Movie Title': 'War Room',
#   'Release Date': '2015-08-28',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/War_Room_(film)',
#   'Genre': 'Drama',
#   'Director 1': 'Alex Kendrick',
#   'Director 2': '',
#   'Cast 1': 'Alex Kendrick',
#   'Cast 2': 'Priscilla Shirer',
#   'Cast 3': 'T.C. Stallings',
#   'Cast 4': 'Beth Moore',
#   'Cast 5': 'Karen Abercrombie',
#   'Budget': '$3,000,000.00',
#   'Revenue': '$73,700,000.00'},
#  {'Movie Title': 'Warcraft',
#   'Release Date': '2016-06-10',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Warcraft_(film)',
#   'Genre': 'Action',
#   'Director 1': 'Duncan Jones',
#   'Director 2': '',
#   'Cast 1': 'Ben Foster',
#   'Cast 2': 'Travis Fimmel',
#   'Cast 3': 'Paula Patton',
#   'Cast 4': 'Toby Kebbell',
#   'Cast 5': 'Dominic Cooper',
#   'Budget': '$160,000,000.00',
#   'Revenue': '$433,500,000.00'},
#  {'Movie Title': 'Warm Bodies',
#   'Release Date': '2013-02-01',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Warm_Bodies_(film)',
#   'Genre': 'Comedy',
#   'Director 1': 'Jonathan Levine',
#   'Director 2': '',
#   'Cast 1': 'Nicholas Hoult',
#   'Cast 2': 'Teresa Palmer',
#   'Cast 3': 'Rob Corddry',
#   'Cast 4': 'John Malkovich',
#   'Cast 5': 'Analeigh Tipton',
#   'Budget': '$35,000,000.00',
#   'Revenue': '$117,000,000.00'},
#  {'Movie Title': 'What Maisie Knew',
#   'Release Date': '2013-05-03',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/What_Maisie_Knew_(film)',
#   'Genre': 'Drama',
#   'Director 1': 'Scott McGehee',
#   'Director 2': 'David Siegel',
#   'Cast 1': 'Julianne Moore',
#   'Cast 2': 'Steve Coogan',
#   'Cast 3': 'Alexander Skarsgård',
#   'Cast 4': 'Joanna Vanderham',
#   'Cast 5': 'Onata Aprile',
#   'Budget': '$5,000,000.00',
#   'Revenue': '$2,700,000.00'},
#  {'Movie Title': "What to Expect When You're Expecting",
#   'Release Date': '2012-05-18',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/What_to_Expect_When_You%2527re_Expecting_(film)',
#   'Genre': 'Comedy',
#   'Director 1': 'Kirk Jones',
#   'Director 2': '',
#   'Cast 1': 'Cameron Diaz',
#   'Cast 2': 'Jennifer Lopez',
#   'Cast 3': 'Brooklyn Decker',
#   'Cast 4': 'Elizabeth Banks',
#   'Cast 5': 'Anna Kendrick',
#   'Budget': '$40,000,000.00',
#   'Revenue': '$84,400,000.00'},
#  {'Movie Title': 'When the Game Stands Tall',
#   'Release Date': '2014-08-04',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/When_the_Game_Stands_Tall',
#   'Genre': 'Religious',
#   'Director 1': 'Thomas Carter',
#   'Director 2': '',
#   'Cast 1': 'Jim Caviezel',
#   'Cast 2': 'Laura Dern',
#   'Cast 3': 'Michael Chiklis',
#   'Cast 4': 'Alexander Ludwig',
#   'Cast 5': '',
#   'Budget': '$15,000,000.00',
#   'Revenue': '$30,100,000.00'},
#  {'Movie Title': 'Whiplash',
#   'Release Date': '2014-01-16',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Whiplash_(2014_film)',
#   'Genre': 'Drama',
#   'Director 1': 'Damien Chazelle',
#   'Director 2': '',
#   'Cast 1': 'J. K. Simmons',
#   'Cast 2': 'Miles Teller',
#   'Cast 3': 'Paul Reiser',
#   'Cast 4': 'Melissa Benoist',
#   'Cast 5': '',
#   'Budget': '$3,300,000.00',
#   'Revenue': '$49,000,000.00'},
#  {'Movie Title': 'Whiskey Tango Foxtrot',
#   'Release Date': '2016-03-04',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Whiskey_Tango_Foxtrot_(film)',
#   'Genre': 'Drama',
#   'Director 1': 'Glenn Ficarra',
#   'Director 2': 'John Requa',
#   'Cast 1': 'Tina Fey',
#   'Cast 2': 'Margot Robbie',
#   'Cast 3': 'Martin Freeman',
#   'Cast 4': 'Billy Bob Thornton',
#   'Cast 5': 'Alfred Molina',
#   'Budget': '$35,000,000.00',
#   'Revenue': '$24,900,000.00'},
#  {'Movie Title': 'White House Down',
#   'Release Date': '2013-06-28',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/White_House_Down',
#   'Genre': 'Action',
#   'Director 1': 'Roland Emmerich',
#   'Director 2': '',
#   'Cast 1': 'Channing Tatum',
#   'Cast 2': 'Jamie Foxx',
#   'Cast 3': 'Maggie Gyllenhaal',
#   'Cast 4': 'James Woods',
#   'Cast 5': 'Richard Jenkins',
#   'Budget': '$150,000,000.00',
#   'Revenue': '$205,000,000.00'},
#  {'Movie Title': 'Wild',
#   'Release Date': '2014-08-29',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Wild_(2014_film)',
#   'Genre': 'Drama',
#   'Director 1': 'Jean-Marc Vallée',
#   'Director 2': '',
#   'Cast 1': 'Reese Witherspoon',
#   'Cast 2': 'Gaby Hoffmann',
#   'Cast 3': 'Michiel Huisman',
#   'Cast 4': 'Charles Baker',
#   'Cast 5': '',
#   'Budget': '$15,000,000.00',
#   'Revenue': '$52,500,000.00'},
#  {'Movie Title': "Winter's Tale",
#   'Release Date': '2014-02-13',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Winter%2527s_Tale_(film)',
#   'Genre': 'Drama',
#   'Director 1': 'Akiva Goldsman',
#   'Director 2': '',
#   'Cast 1': 'Colin Farrell',
#   'Cast 2': 'Russell Crowe',
#   'Cast 3': 'Jessica Brown Findlay',
#   'Cast 4': 'Jennifer Connelly',
#   'Cast 5': 'Will Smith',
#   'Budget': '$60,000,000.00',
#   'Revenue': '$31,100,000.00'},
#  {'Movie Title': 'Wish I Was Here',
#   'Release Date': '2014-01-18',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Wish_I_Was_Here',
#   'Genre': 'Drama',
#   'Director 1': 'Zach Braff',
#   'Director 2': '',
#   'Cast 1': 'Zach Braff',
#   'Cast 2': 'Kate Hudson',
#   'Cast 3': 'Jim Parsons',
#   'Cast 4': 'Mandy Patinkin',
#   'Cast 5': 'Ashley Greene',
#   'Budget': '$6,000,000.00',
#   'Revenue': '$5,500,000.00'},
#  {'Movie Title': 'Woman in Gold',
#   'Release Date': '2015-04-01',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Woman_in_Gold_(film)',
#   'Genre': 'Drama',
#   'Director 1': 'Simon Curtis',
#   'Director 2': '',
#   'Cast 1': 'Helen Mirren',
#   'Cast 2': 'Ryan Reynolds',
#   'Cast 3': 'Daniel Brühl',
#   'Cast 4': 'Katie Holmes',
#   'Cast 5': 'Tatiana Maslany',
#   'Budget': '$11,000,000.00',
#   'Revenue': '$61,600,000.00'},
#  {'Movie Title': "Won't Back Down",
#   'Release Date': '2012-09-28',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Won%2527t_Back_Down_(film)',
#   'Genre': 'Drama',
#   'Director 1': 'Daniel Barnz',
#   'Director 2': '',
#   'Cast 1': 'Viola Davis',
#   'Cast 2': 'Maggie Gyllenhaal',
#   'Cast 3': 'Holly Hunter',
#   'Cast 4': 'Ving Rhames',
#   'Cast 5': 'Rosie Perez',
#   'Budget': '$19,000,000.00',
#   'Revenue': '$5,400,000.00'},
#  {'Movie Title': 'Woodlawn',
#   'Release Date': '2015-10-16',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Woodlawn_(film)',
#   'Genre': 'Drama',
#   'Director 1': 'The Erwin Brothers',
#   'Director 2': '',
#   'Cast 1': 'Sean Astin',
#   'Cast 2': 'Nic Bishop',
#   'Cast 3': 'Caleb Castille',
#   'Cast 4': 'Sherri Shepherd',
#   'Cast 5': 'Jon Voight',
#   'Budget': '$13,000,000.00',
#   'Revenue': '$14,400,000.00'},
#  {'Movie Title': 'World War Z',
#   'Release Date': '2013-06-21',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/World_War_Z_(film)',
#   'Genre': 'Action',
#   'Director 1': 'Marc Forster',
#   'Director 2': '',
#   'Cast 1': 'Brad Pitt',
#   'Cast 2': 'Mireille Enos',
#   'Cast 3': 'James Badge Dale',
#   'Cast 4': 'Daniella Kertesz',
#   'Cast 5': 'Matthew Fox',
#   'Budget': '$190,000,000.00',
#   'Revenue': '$540,000,000.00'},
#  {'Movie Title': 'Wrath of the Titans',
#   'Release Date': '2012-03-30',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Wrath_of_the_Titans',
#   'Genre': 'Action',
#   'Director 1': 'Jonathan Liebesman',
#   'Director 2': '',
#   'Cast 1': 'Sam Worthington',
#   'Cast 2': 'Liam Neeson',
#   'Cast 3': 'Ralph Fiennes',
#   'Cast 4': 'Edgar Ramirez',
#   'Cast 5': 'Rosamund Pike',
#   'Budget': '$150,000,000.00',
#   'Revenue': '$305,300,000.00'},
#  {'Movie Title': 'X-Men: Apocalypse',
#   'Release Date': '2016-05-09',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/X-Men:_Apocalypse',
#   'Genre': 'Action',
#   'Director 1': 'Bryan Singer',
#   'Director 2': '',
#   'Cast 1': 'James McAvoy',
#   'Cast 2': 'Michael Fassbender',
#   'Cast 3': 'Jennifer Lawrence',
#   'Cast 4': 'Oscar Isaac',
#   'Cast 5': 'Nicholas Hoult',
#   'Budget': '$178,000,000.00',
#   'Revenue': '$544,600,000.00'},
#  {'Movie Title': 'X-Men: Days of Future Past',
#   'Release Date': '2014-05-10',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/X-Men:_Days_of_Future_Past',
#   'Genre': 'Action',
#   'Director 1': 'Bryan Singer',
#   'Director 2': '',
#   'Cast 1': 'Hugh Jackman',
#   'Cast 2': 'James McAvoy',
#   'Cast 3': 'Michael Fassbender',
#   'Cast 4': 'Halle Berry',
#   'Cast 5': 'Jennifer Lawrence',
#   'Budget': '$200,000,000.00',
#   'Revenue': '$747,900,000.00'},
#  {'Movie Title': "You're Next",
#   'Release Date': '2013-08-23',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/You%2527re_Next',
#   'Genre': 'Horror',
#   'Director 1': 'Adam Wingard',
#   'Director 2': '',
#   'Cast 1': 'Sharni Vinson',
#   'Cast 2': 'Joe Swanberg',
#   'Cast 3': 'AJ Bowen',
#   'Cast 4': 'Nicholas Tucci',
#   'Cast 5': 'Barbara Crampton',
#   'Budget': '$1,000,000.00',
#   'Revenue': '$26,800,000.00'},
#  {'Movie Title': 'Zero Dark Thirty',
#   'Release Date': '2012-12-19',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Zero_Dark_Thirty',
#   'Genre': 'Drama',
#   'Director 1': 'Kathryn Bigelow',
#   'Director 2': '',
#   'Cast 1': 'Jessica Chastain',
#   'Cast 2': 'Chris Pratt',
#   'Cast 3': 'Joel Edgerton',
#   'Cast 4': 'Kyle Chandler',
#   'Cast 5': 'Jason Clarke',
#   'Budget': '$40,000,000.00',
#   'Revenue': '$132,800,000.00'},
#  {'Movie Title': 'Zhong Kui: Snow Girl and the Dark Crystal',
#   'Release Date': '2015-02-19',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Zhong_Kui:_Snow_Girl_and_the_Dark_Crystal',
#   'Genre': 'Romance',
#   'Director 1': 'Peter Pau',
#   'Director 2': '',
#   'Cast 1': 'Li Bingbing',
#   'Cast 2': 'Chen Kun',
#   'Cast 3': 'Yang Zishan',
#   'Cast 4': 'Winston Chao',
#   'Cast 5': "Bao Bei'er",
#   'Budget': '$30,000,000.00',
#   'Revenue': '$64,470,000.00'},
#  {'Movie Title': 'Zoolander 2',
#   'Release Date': '2016-02-12',
#   'Wikipedia URL': 'https://en.wikipedia.org/wiki/Zoolander_2',
#   'Genre': 'Comedy',
#   'Director 1': 'Ben Stiller',
#   'Director 2': '',
#   'Cast 1': 'Ben Stiller',
#   'Cast 2': 'Owen Wilson',
#   'Cast 3': 'Christine Taylor',
#   'Cast 4': 'Will Ferrell',
#   'Cast 5': 'Penélope Cruz',
#   'Budget': '$50,000,000.00',
#   'Revenue': '$56,000,000.00'}]

# %%
def exibir_planilha(planilha):
    dados = planilha.get_all_records()
    df = pd.DataFrame(dados)
    return df

# %%
# Ordenar a os dados pela coluna Release Date
planilha.sort((2, "asc"))

exibir_planilha(planilha)
# Out:
#                   Movie Title Release Date  \
# 0            The Devil Inside   2012-01-06
# 1                   Red Tails   2012-01-20
# 2          Declaration of War   2012-01-27
# 3              Man on a Ledge   2012-01-27
# 4           One for the Money   2012-01-27
# ..                        ...          ...
# 503  Kubo and the Two Strings   2016-08-19
# 504                  War Dogs   2016-08-19
# 505             Don't Breathe   2016-08-26
# 506            Hands of Stone   2016-08-26
# 507    Mechanic: Resurrection   2016-08-26
#
#                                          Wikipedia URL      Genre  \
# 0    https://en.wikipedia.org/wiki/The_Devil_Inside...     Horror
# 1              https://en.wikipedia.org/wiki/Red_Tails      Drama
# 2    https://en.wikipedia.org/wiki/Declaration_of_W...    Romance
# 3         https://en.wikipedia.org/wiki/Man_on_a_Ledge     Action
# 4    https://en.wikipedia.org/wiki/One_for_the_Mone...      Crime
# ..                                                 ...        ...
# 503  https://en.wikipedia.org/wiki/Kubo_and_the_Two...    Fantasy
# 504  https://en.wikipedia.org/wiki/War_Dogs_(2016_f...      Crime
# 505  https://en.wikipedia.org/wiki/Don%2527t_Breath...   Thriller
# 506       https://en.wikipedia.org/wiki/Hands_of_Stone  Biography
# 507  https://en.wikipedia.org/wiki/Mechanic:_Resurr...     Action
#
#               Director 1 Director 2                       Cast 1  \
# 0     William Brent Bell                           Suzan Crowley
# 1      Anthony Hemingway                        Cuba Gooding Jr.
# 2       Valérie Donzelli             Valérie Donzelli (director)
# 3             Asger Leth                         Sam Worthington
# 4    Julie Anne Robinson                         Katherine Heigl
# ..                   ...        ...                          ...
# 503        Travis Knight                           Art Parkinson
# 504        Todd Phillips                              Jonah Hill
# 505         Fede Alvarez                          Dylan Minnette
# 506  Jonathan Jakubowicz                           Édgar Ramírez
# 507        Dennis Gansel                           Jason Statham
#
#                   Cast 2            Cast 3           Cast 4           Cast 5  \
# 0       Fernanda Andrade  Simon Quarterman     Evan Helmuth
# 1            Nate Parker     David Oyelowo     Daniela Ruah  Terrence Howard
# 2
# 3              Ed Harris   Elizabeth Banks       Jamie Bell    Kyra Sedgwick
# 4        Debbie Reynolds      Jason O'Mara   Daniel Sunjata  Sherri Shepherd
# ..                   ...               ...              ...              ...
# 503  Matthew McConaughey       Rooney Mara  Charlize Theron    Ralph Fiennes
# 504         Miles Teller      Ana de Armas      J. B. Blanc
# 505         Stephen Lang    Daniel Zovatto
# 506       Robert De Niro             Usher     Ellen Barkin     Ana de Armas
# 507         Jessica Alba   Tommy Lee Jones    Michelle Yeoh
#
#              Budget          Revenue
# 0     $1,000,000.00  $101,800,000.00
# 1    $58,000,000.00   $50,400,000.00
# 2     $1,500,000.00    $6,500,000.00
# 3    $42,000,000.00   $46,200,000.00
# 4    $40,000,000.00   $36,900,000.00
# ..              ...              ...
# 503  $60,000,000.00   $27,600,000.00
# 504  $40,000,000.00   $42,700,000.00
# 505   $9,900,000.00   $28,300,000.00
# 506  $20,000,000.00    $1,700,000.00
# 507  $40,000,000.00    $7,500,000.00
#
# [508 rows x 13 columns]

# %%
# Ordenar a os dados pela coluna Release Date seguido da ordenação da coluna Movie Title
planilha.sort((2, 'asc'), (1, 'asc'))

exibir_planilha(planilha)
# Out:
#                   Movie Title Release Date  \
# 0            The Devil Inside   2012-01-06
# 1                   Red Tails   2012-01-20
# 2          Declaration of War   2012-01-27
# 3              Man on a Ledge   2012-01-27
# 4           One for the Money   2012-01-27
# ..                        ...          ...
# 503  Kubo and the Two Strings   2016-08-19
# 504                  War Dogs   2016-08-19
# 505             Don't Breathe   2016-08-26
# 506            Hands of Stone   2016-08-26
# 507    Mechanic: Resurrection   2016-08-26
#
#                                          Wikipedia URL      Genre  \
# 0    https://en.wikipedia.org/wiki/The_Devil_Inside...     Horror
# 1              https://en.wikipedia.org/wiki/Red_Tails      Drama
# 2    https://en.wikipedia.org/wiki/Declaration_of_W...    Romance
# 3         https://en.wikipedia.org/wiki/Man_on_a_Ledge     Action
# 4    https://en.wikipedia.org/wiki/One_for_the_Mone...      Crime
# ..                                                 ...        ...
# 503  https://en.wikipedia.org/wiki/Kubo_and_the_Two...    Fantasy
# 504  https://en.wikipedia.org/wiki/War_Dogs_(2016_f...      Crime
# 505  https://en.wikipedia.org/wiki/Don%2527t_Breath...   Thriller
# 506       https://en.wikipedia.org/wiki/Hands_of_Stone  Biography
# 507  https://en.wikipedia.org/wiki/Mechanic:_Resurr...     Action
#
#               Director 1 Director 2                       Cast 1  \
# 0     William Brent Bell                           Suzan Crowley
# 1      Anthony Hemingway                        Cuba Gooding Jr.
# 2       Valérie Donzelli             Valérie Donzelli (director)
# 3             Asger Leth                         Sam Worthington
# 4    Julie Anne Robinson                         Katherine Heigl
# ..                   ...        ...                          ...
# 503        Travis Knight                           Art Parkinson
# 504        Todd Phillips                              Jonah Hill
# 505         Fede Alvarez                          Dylan Minnette
# 506  Jonathan Jakubowicz                           Édgar Ramírez
# 507        Dennis Gansel                           Jason Statham
#
#                   Cast 2            Cast 3           Cast 4           Cast 5  \
# 0       Fernanda Andrade  Simon Quarterman     Evan Helmuth
# 1            Nate Parker     David Oyelowo     Daniela Ruah  Terrence Howard
# 2
# 3              Ed Harris   Elizabeth Banks       Jamie Bell    Kyra Sedgwick
# 4        Debbie Reynolds      Jason O'Mara   Daniel Sunjata  Sherri Shepherd
# ..                   ...               ...              ...              ...
# 503  Matthew McConaughey       Rooney Mara  Charlize Theron    Ralph Fiennes
# 504         Miles Teller      Ana de Armas      J. B. Blanc
# 505         Stephen Lang    Daniel Zovatto
# 506       Robert De Niro             Usher     Ellen Barkin     Ana de Armas
# 507         Jessica Alba   Tommy Lee Jones    Michelle Yeoh
#
#              Budget          Revenue
# 0     $1,000,000.00  $101,800,000.00
# 1    $58,000,000.00   $50,400,000.00
# 2     $1,500,000.00    $6,500,000.00
# 3    $42,000,000.00   $46,200,000.00
# 4    $40,000,000.00   $36,900,000.00
# ..              ...              ...
# 503  $60,000,000.00   $27,600,000.00
# 504  $40,000,000.00   $42,700,000.00
# 505   $9,900,000.00   $28,300,000.00
# 506  $20,000,000.00    $1,700,000.00
# 507  $40,000,000.00    $7,500,000.00
#
# [508 rows x 13 columns]

# %% [markdown]
# Utilizando a Função SORT

# %%
spreadsheet_PartyPlan = client.open(
    title="Course_05-Party_Plan_Spreadsheet", 
    folder_id="1VeZ1jCJLUNXSDYpJrchCjPTtr5iZ7BKw")

# %%
spreadsheet_PartyPlan = spreadsheet_PartyPlan.get_worksheet(0)

# %%
pd.DataFrame(spreadsheet_PartyPlan.get_all_records())
# Out:
#     Guest Name  Table Number  Dietary Restriction  Sent Invitation  \
# 0         Jack             2           Vegetarian               No
# 1         Omar             1                 None              Yes
# 2         Aida             3                 None              Yes
# 3        Nancy             3                 None               No
# 4       Jianyu             2           Vegetarian              Yes
# 5
# 6
# 7   Guest Name  Table Number  Dietary Restriction  Sent Invitation
# 8         Omar             1                 None              Yes
# 9         Jack             2           Vegetarian               No
# 10      Jianyu             2           Vegetarian              Yes
# 11        Aida             3                 None              Yes
# 12       Nancy             3                 None               No
#
#                 Row Index
# 0                       5
# 1                       4
# 2                       3
# 3                       2
# 4                       1
# 5
# 6
# 7                 Formula
# 8   =SORT(A2:D6, 2, TRUE)
# 9
# 10
# 11
# 12

# %%
spreadsheet_PartyPlan.update([['Guest Name Sort', 'Table Number Sort', 
                               'Dietary Restriction Sort', 'Sent Invitation Sort', 
                               'Row Index Sort']], "G1:L1")
# Out:
# {'spreadsheetId': '1oP2L6DTJpAfSgnDyi8h-97dO6bf9BgpEtWolJderJFk',
#  'updatedRange': "'Party Plan'!G1:K1",
#  'updatedRows': 1,
#  'updatedColumns': 5,
#  'updatedCells': 5}

# %%
spreadsheet_PartyPlan.update([['=SORT(A2:E6; 2; TRUE)']], "G2", raw=False)
# Out:
# {'spreadsheetId': '1oP2L6DTJpAfSgnDyi8h-97dO6bf9BgpEtWolJderJFk',
#  'updatedRange': "'Party Plan'!G2",
#  'updatedRows': 1,
#  'updatedColumns': 1,
#  'updatedCells': 1}

# %%
pd.DataFrame(spreadsheet_PartyPlan.get_all_records())
# Out:
#     Guest Name  Table Number  Dietary Restriction  Sent Invitation  \
# 0         Jack             2           Vegetarian               No
# 1         Omar             1                 None              Yes
# 2         Aida             3                 None              Yes
# 3        Nancy             3                 None               No
# 4       Jianyu             2           Vegetarian              Yes
# 5
# 6
# 7   Guest Name  Table Number  Dietary Restriction  Sent Invitation
# 8         Omar             1                 None              Yes
# 9         Jack             2           Vegetarian               No
# 10      Jianyu             2           Vegetarian              Yes
# 11        Aida             3                 None              Yes
# 12       Nancy             3                 None               No
#
#                 Row Index   Guest Name Sort Table Number Sort  \
# 0                       5              Omar                 1
# 1                       4              Jack                 2
# 2                       3            Jianyu                 2
# 3                       2              Aida                 3
# 4                       1             Nancy                 3
# 5
# 6
# 7                 Formula
# 8   =SORT(A2:D6, 2, TRUE)
# 9
# 10
# 11
# 12
#
#    Dietary Restriction Sort Sent Invitation Sort Row Index Sort
# 0                      None                  Yes              4
# 1                Vegetarian                   No              5
# 2                Vegetarian                  Yes              1
# 3                      None                  Yes              3
# 4                      None                   No              2
# 5
# 6
# 7
# 8
# 9
# 10
# 11
# 12
